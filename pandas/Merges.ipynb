# %%
import pandas as pd
import numpy as np
import re
#files
courses = pd.read_csv('/content/courses.csv')
nov = pd.read_csv('/content/reg-month1.csv')
dec = pd.read_csv('/content/reg-month2.csv')
matches = pd.read_csv('/content/matches.csv')
deli  = pd.read_csv('/content/deliveries.csv')
student = pd.read_csv('/content/students.csv')

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
df1 = pd.DataFrame(
    {
        'name': ['jibran','samar','ali'],
        'Father_name':['Saleem' , 'abc' ,'xyz']
    }
)
df2 = pd.DataFrame(
    {
        "Age": [40,50,60],
        'name' : [ 'jawwad','samar','ali'],
        'Educaion': ['undergradute','postgraduate','under']
    }
)
df1
df1.merge(df2,on ='name',how='left')
# Out:
#      name Father_name   Age      Educaion
# 0  jibran      Saleem   NaN           NaN
# 1   samar         abc  50.0  postgraduate
# 2     ali         xyz  60.0         under

# %%
df2
# Out:
#    Age    name      Educaion
# 0   40  jawwad  undergradute
# 1   50   samar  postgraduate
# 2   60     ali         under

# %%
#concat
total_regs = pd.concat([nov,dec],ignore_index = True).sort_values(by='student_id')
#inner join
total_regs.merge(courses,on = 'course_id',how = 'inner')
# Out:
#     student_id  course_id       course_name  price
# 0            1          9            plotly    699
# 1            1         10           pyspark   2499
# 2            1          1            python   2499
# 3            1          6          power bi   1899
# 4            2          5           tableau   2499
# 5            3          3     data analysis   4999
# 6            3          5           tableau   2499
# 7            7          6          power bi   1899
# 8            7          7          ms sxcel   1599
# 9            7          8            pandas   1099
# 10           7          2               sql   3499
# 11           7         10           pyspark   2499
# 12          11          8            pandas   1099
# 13          11          7          ms sxcel   1599
# 14          11         10           pyspark   2499
# 15          12          5           tableau   2499
# 16          12          7          ms sxcel   1599
# ...

# %%
#left join : all elements from left and jo match kr rha h , col uski keys match kro sare elemets s if left key is present in right then all rows are add in it
#if lefy key does not found in right right dataframe then nan is placed
df1 = pd.DataFrame(
    {
        'name': ['jibran','samar','ali'],
        'Father_name':['Saleem' , 'abc' ,'xyz']
    }
)
df2 = pd.DataFrame(
    {
        "Age": [40,50,60],
        'name' : [ 'jawwad','samar','ali'],
        'Educaion': ['undergradute','postgraduate','under']
    }
)

df1.merge(df2,on ='name',how='left')
#left
# total_regs
courses.merge(total_regs,on="course_id",how='left')   # course_id course_name price student_id
total_regs

# %%
#right join
#same as left but all right are included

#outer :
#all from right and left are included

# %%
#TOTAL REVENEW GEN BY THE COURESES

total_regs
# student
# courses : # course id , course name , price
x = total_regs.merge(courses,on ='course_id',how='inner')
x.groupby('course_name')['price'].sum().sum()
# Out:
# 154247

# %%
#month by month reg
pd.concat([nov,dec],keys=['nov','dec']).reset_index().merge(courses,on ='course_id',how='inner').groupby('level_0')['price'].sum()
# Out:
# level_0
# dec    65072
# nov    89175
# Name: price, dtype: int64

# %%
#print regis table
#cols - > name -> course  - > price

student # std id ,std name , partner
courses#  course id , course name price
total_regs #student id and course id
total_regs.merge(student,on='student_id',how='inner').merge(courses,on = 'course_id' , how = 'inner')[['name','course_name','price']]
# Out:
#                   name       course_name  price
# 0        Kailash Harjo            plotly    699
# 1        Kailash Harjo           pyspark   2499
# 2        Kailash Harjo            python   2499
# 3        Kailash Harjo          power bi   1899
# 4          Esha Butala           tableau   2499
# 5       Parveen Bhalla     data analysis   4999
# 6       Parveen Bhalla           tableau   2499
# 7         Tarun Thaker          power bi   1899
# 8         Tarun Thaker          ms sxcel   1599
# 9         Tarun Thaker            pandas   1099
# 10        Tarun Thaker               sql   3499
# 11        Tarun Thaker           pyspark   2499
# 12  David Mukhopadhyay            pandas   1099
# 13  David Mukhopadhyay          ms sxcel   1599
# 14  David Mukhopadhyay           pyspark   2499
# 15          Radha Dutt           tableau   2499
# 16          Radha Dutt          ms sxcel   1599
# 17          Radha Dutt            python   2499
# 18          Radha Dutt           pyspark   2499
# ...

# %%
#find stundets take course in both month
ids = np.intersect1d(nov['student_id'],dec['student_id'])
student[student['student_id'].isin(ids)]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
#course with no enrol

courses
total_regs
x  = np.setdiff1d(courses['course_id'],total_regs['course_id'])
courses[courses['course_id'].isin(x)]
# Out:
#     course_id course_name  price
# 10         11       Numpy    699
# 11         12         C++   1299

# %%
#print partner name  using inner join

student.merge(student , how = 'inner' , left_on = 'partner' , right_on = 'student_id')[['name_x','name_y']]

matches
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
#find stadium with highest sixes/fours ratio
deli
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...
