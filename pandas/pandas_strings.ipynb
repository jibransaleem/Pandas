# %%
import pandas as pd
import numpy as np
import re
exp  = pd.read_csv('/content/expense_data (1).csv')
titanic =  pd.read_csv('/content/titanic (1).csv')

# %%
# What are vectorized operations
a = np.array([1,2,3,4])
a * 4

# %%
# problem in vectorized opertions in vanilla python
s = ['cat','mat',None,'rat']

[i.startswith('c') for i in s]# dont deal good with missing values : throws error

# %%
# How pandas solves this issue?

s = pd.Series(['cat','mat',None,'rat'])
# string accessor
s.str.startswith('c')

# fast and optimized

# %%
#common fucntions
data1 = titanic['Name'].str.upper()
titanic['Name'].str.capitalize()
titanic['Name'].str.title()
#len
titanic['Name'].str.len()
#split
titanic['Name'].str.split(',')
#strip
titanic['Name'].str.strip()
#longest name
mask  = titanic['Name'].str.len() == titanic['Name'].str.len().max()

titanic['Name'][mask]
# Out:
# 307    Penasco y Castellana, Mrs. Victor de Satode (M...
# Name: Name, dtype: object

# %%
#split -> get
#in order to perform vectorized string opeartion always use str before fun ex str.get
#pass index to get and it will extract data from the index from all lists
# make col of their title : mr , mrs

#titanic['Title'] = titanic['Name'].str.split(',').str.get(1).str.split('.').str.get(0)
#total mr and mrs
titanic.groupby('Title').size().sort_values(ascending = False)

# in split agr m chahta first comma pr h split ho like jibran,saleem,hashim .
# i want to split like that jibran  saleem , hashim  so use n=1
#split(',' , n =1)
#or
titanic[['Title','Firstname']]= titanic['Name'].str.split(',').str.get(1).str.split('.',expand  = True)[[0,1]]

#expand  = True convert series into dataframe

# %%
#replace
titanic['Title'] = titanic['Title'].str.replace('Ms','Miss')
titanic['Title'].value_counts()
# Out:
# Title
# Mr              517
# Miss            183
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Major             2
# Mlle              2
# Col               2
# Don               1
# Mme               1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
#filtering
#name starting with a
titanic['Firstname'].str.startswith('O')
#name ending with z : use endswith

#isdigit()/isalpha()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Firstname, Length: 891, dtype: bool

# %%
#contains func
titanic['Firstname'].str.contains('john' , case = False)

#case = False means , capital small letter not matter
#for advance filtering use may use regex
#using regex
pattern = r'^[aeiouAEIOU]+.+[aeiouAEIOU]$'
titanic['Firstname'].str.contains(pattern) # will return boolean series
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#slicing

titanic['Name'].str[0:4] # fetching 5 letters from all names
titanic['Name'].str[::-1] # reverse the name
# Out:
# 0                                sirraH newO .rM ,dnuarB
# 1      )reyahT sggirB ecnerolF( yeldarB nhoJ .srM ,sg...
# 2                                 aniaL .ssiM ,nenikkieH
# 3           )leeP yaM yliL( htaeH seuqcaJ .srM ,ellertuF
# 4                               yrneH mailliW .rM ,nellA
#                              ...
# 886                                sazouJ .veR ,alivtnoM
# 887                         htidE teragraM .ssiM ,maharG
# 888             "eirraC" neleH enirehtaC .ssiM ,notsnhoJ
# 889                                llewoH lraK .rM ,rheB
# 890                                  kcirtaP .rM ,yelooD
# Name: Name, Length: 891, dtype: object
