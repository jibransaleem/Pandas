# %%
import numpy as np
import pandas as pd

data = pd.DataFrame(
    [
        [100,200,300],
        [1.2,4.5,8],
        [60,23,8],
        [60,23,8]
    ],columns=['Lpa','Iq','Marks']

)
runs = pd.read_csv('/content/batsman_runs_ipl.csv')
dia = pd.read_csv('/content/diabetes.csv')
ipl = pd.read_csv('/content/ipl-matches.csv')
movie = pd.read_csv('/content/movies.csv')
data = {
    "college": ["College A", "College B", np.nan, "College D"],
    "name": ["Alice", np.nan, "Charlie", "David"],
    "lpa": [5.5, 6.7, np.nan, 4.3],
    "gpa": [3.8, 3.5, 3.9, np.nan]
}
df = pd.DataFrame(data)

# %% [markdown]
# isnull() : for both
#
# notnull() : for both
#
# hasnans :  for series only

# %%
df[df['name'].isnull()] # which are null   # sereis
df['name'].notnull()#which are not null  #series
df['name'].hasnans# tell if it has nan values or not #series
df.isnull()
df.notnull()
# Out:
#    college   name    lpa    gpa
# 0     True   True   True   True
# 1     True  False   True   True
# 2    False   True  False   True
# 3     True   True   True  False

# %% [markdown]
# dropna() : - > both

# %%
df.dropna()# in datframe : if any row has missing value it remove whole row
# so it removes alot of data , so to improve it , change its paramater from any to all: if all values are null then the row is removed
df.dropna(how='all')
# want if college is null , so remove all row
df.dropna(subset=['college'])
#drop if agr ksi bh ik m ho (college , name )
df.dropna(subset=['college','name'])
# Out:
#      college   name  lpa  gpa
# 0  College A  Alice  5.5  3.8
# 3  College D  David  4.3  NaN

# %% [markdown]
# fillna() -> both

# %%
df.fillna(0)
df.fillna(method='bfill')
# Out:
# <ipython-input-173-8a733dfedbdd>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#      college     name  lpa  gpa
# 0  College A    Alice  5.5  3.8
# 1  College B  Charlie  6.7  3.5
# 2  College D  Charlie  4.3  3.9
# 3  College D    David  4.3  NaN

# %% [markdown]
# drop_duplicates()  : -> both

# %%
a = pd.Series([1,2,3,1,2,3,1,10,])
a.drop_duplicates()
d = a.reset_index().reset_index()
d.drop_duplicates(keep='first') #first(by default),last,
#find when chokli played its last match in dehli
a = ipl['Team1'] =='Royal Challengers Bangalore'
b =ipl['Team2'] =='Royal Challengers Bangalore'
chokli_play = (
    ipl[a]['Team1Players'].apply(lambda x: "V Kohli" in x) |
    ipl[b]['Team2Players'].apply(lambda x: "V Kohli" in x)
)
ipl['VK'] = chokli_play
#or
ipl[(ipl['VK']==True) & (ipl['City']=='Delhi')].drop_duplicates(subset = ['City','Vk'],keep='first')
ipl['All'] = ipl['Team1']+ipl['Team2']
ipl['Vk'] =  ipl['All'].apply(lambda x: "V kohli" in x)
ipl[(ipl['City']=='Dehli')&(ipl['Vk'])==True].drop_duplicates(subset = ['City','Vk'],keep='first')
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2, Virat_on_field, VK, All, Vk]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# drop () - > both

# %%
temp  = pd.Series([1,2,3,4,5])
temp.drop(index=[0,2])
df.drop(columns=['lpa','gpa'],index=[1,2])
# Out:
#      college   name
# 0  College A  Alice
# 3  College D  David

# %% [markdown]
# apply() :-> both
